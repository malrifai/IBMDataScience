# %% [markdown]
# # This notebook will be mainly used for the capstone project

# %%
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# ### Scraping Data From Wikipedia

# %%
headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }

url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
req = requests.get(url, headers)
soup = BeautifulSoup(req.content, 'html.parser')

# %% [markdown]
# ### Pre-Processing Data

# %%
table= soup.find("table")
table
table_rows = table.find_all('tr')
res = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td if tr.text.strip()]
    if row:
     
        res.append(row)


df = pd.DataFrame(res, columns=["Postal Code", "Borough", "Neighborhood"])

df = df[df.Borough != 'Not assigned']

# %%
df = df.groupby(['Postal Code','Borough'])['Neighborhood'].apply(', '.join).reset_index()
df.head(10)
#change column order
# Out:
#   Postal Code      Borough                                     Neighborhood
# 0         M1B  Scarborough                                   Malvern, Rouge
# 1         M1C  Scarborough           Rouge Hill, Port Union, Highland Creek
# 2         M1E  Scarborough                Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                           Woburn
# 4         M1H  Scarborough                                        Cedarbrae
# 5         M1J  Scarborough                              Scarborough Village
# 6         M1K  Scarborough      Kennedy Park, Ionview, East Birchmount Park
# 7         M1L  Scarborough                  Golden Mile, Clairlea, Oakridge
# 8         M1M  Scarborough  Cliffside, Cliffcrest, Scarborough Village West
# 9         M1N  Scarborough                      Birch Cliff, Cliffside West

# %%
df.shape
# Out:
# (103, 5)

# %% [markdown]
# ### create  dataframe With Geo Locations

# %%
df['latitude']=''
df['longitude']=''
import geocoder # import geocoder
# initialize your variable to None
for ind in df.index: 
     postal_code=  df['Postal Code'][ind]
     lat_lng_coords = None
   
    # loop until you get the coordinates
     while(lat_lng_coords is None):
  #    print(postal_code)
      #print('Toronto, Ontario'.format(postal_code))
      #g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
      g = geocoder.arcgis('{}, Toronto, Ontario'.format(postal_code)) 
      lat_lng_coords = g.latlng
      #print("postal_code:"+postal_code+" lat_lng_coords:"+str(lat_lng_coords)+"")  
     df['latitude'][ind] = lat_lng_coords[0]
     df['longitude'][ind] = lat_lng_coords[1]      
df
# Out:
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# 26          M3B        North York
# 27          M3C        North York
# 28          M3H        North York
# 29          M3J        North York
# ..          ...               ...
# 73          M6C              York
# 74          M6E              York
# 75          M6G  Downtown Toronto
# 76          M6H      West Toronto
# 77          M6J      West Toronto
# 78          M6K      West Toronto
# 79          M6L        North York
# 80          M6M              York
# 81          M6N              York
# 82          M6P      West Toronto
# 83          M6R      West Toronto
# 84          M6S      West Toronto
# 85          M7A  Downtown Toronto
# 86          M7R       Mississauga
# 87          M7Y      East Toronto
# 88          M8V         Etobicoke
# 89          M8W         Etobicoke
# 90          M8X         Etobicoke
# 91          M8Y         Etobicoke
# 92          M8Z         Etobicoke
# 93          M9A         Etobicoke
# 94          M9B         Etobicoke
# 95          M9C         Etobicoke
# 96          M9L        North York
# 97          M9M        North York
# 98          M9N              York
# 99          M9P         Etobicoke
# 100         M9R         Etobicoke
# 101         M9V         Etobicoke
# 102         M9W         Etobicoke
#
#                                           Neighborhood latitude longitude
# 0                                       Malvern, Rouge  43.8086  -79.1899
# 1               Rouge Hill, Port Union, Highland Creek  43.7858  -79.1574
# 2                    Guildwood, Morningside, West Hill  43.7658  -79.1853
# 3                                               Woburn  43.7715  -79.2181
# 4                                            Cedarbrae  43.7688  -79.2388
# 5                                  Scarborough Village  43.7442  -79.2287
# 6          Kennedy Park, Ionview, East Birchmount Park  43.7269  -79.2657
# 7                      Golden Mile, Clairlea, Oakridge  43.7133  -79.2849
# 8      Cliffside, Cliffcrest, Scarborough Village West  43.7235  -79.2284
# 9                          Birch Cliff, Cliffside West  43.6964  -79.2656
# 10   Dorset Park, Wexford Heights, Scarborough Town...  43.7613  -79.2699
# 11                                   Wexford, Maryvale    43.75  -79.3005
# 12                                           Agincourt  43.7939  -79.2657
# 13             Clarks Corners, Tam O'Shanter, Sullivan  43.7849  -79.3047
# 14   Milliken, Agincourt North, Steeles East, L'Amo...   43.818  -79.2809
# 15                       Steeles West, L'Amoreaux West  43.8005  -79.3218
# 16                                         Upper Rouge  43.8348  -79.2041
# 17                                   Hillcrest Village  43.8026  -79.3566
# 18                        Fairview, Henry Farm, Oriole  43.7803  -79.3487
# 19                                     Bayview Village  43.7806  -79.3769
# 20                            York Mills, Silver Hills  43.7494  -79.3807
# 21                             Willowdale, Newtonbrook  43.7918  -79.4064
# 22                         Willowdale, Willowdale East  43.7691  -79.4137
# 23                                     York Mills West  43.7503  -79.3984
# 24                         Willowdale, Willowdale West  43.7799  -79.4452
# 25                                           Parkwoods  43.7529  -79.3356
# 26                                           Don Mills  43.7489  -79.3572
# 27                                           Don Mills  43.7221   -79.352
# 28     Bathurst Manor, Wilson Heights, Downsview North  43.7574  -79.4424
# 29                     Northwood Park, York University  43.7649  -79.4925
# ..                                                 ...      ...       ...
# 73                                  Humewood-Cedarvale  43.6917    -79.43
# 74                                 Caledonia-Fairbanks  43.6891  -79.4507
# 75                                            Christie  43.6686  -79.4204
# 76                        Dufferin, Dovercourt Village  43.6649  -79.4387
# 77                            Little Portugal, Trinity  43.6486  -79.4178
# 78        Brockton, Parkdale Village, Exhibition Place  43.6399  -79.4312
# 79            North Park, Maple Leaf Park, Upwood Park  43.7135  -79.4887
# 80    Del Ray, Mount Dennis, Keelsdale and Silverthorn  43.6951  -79.4872
# 81                       Runnymede, The Junction North  43.6769  -79.4787
# 82                       High Park, The Junction South  43.6587  -79.4631
# 83                              Parkdale, Roncesvalles  43.6478  -79.4484
# 84                                  Runnymede, Swansea  43.6497  -79.4827
# 85         Queen's Park, Ontario Provincial Government  43.6618  -79.3894
# 86               Canada Post Gateway Processing Centre  43.6487  -79.3854
# 87   Business reply mail Processing Centre, South C...  43.6487  -79.3854
# 88        New Toronto, Mimico South, Humber Bay Shores  43.6101  -79.4998
# 89                              Alderwood, Long Branch  43.6009  -79.5404
# 90       The Kingsway, Montgomery Road, Old Mill North  43.6533  -79.5098
# 91   Old Mill South, King's Mill Park, Sunnylea, Hu...  43.6328   -79.493
# 92   Mimico NW, The Queensway West, South of Bloor,...  43.6255   -79.526
# 93             Islington Avenue, Humber Valley Village  43.6675   -79.529
# 94   West Deane Park, Princess Gardens, Martin Grov...    43.65  -79.5541
# 95   Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.6378  -79.5765
# 96                                       Humber Summit  43.7594  -79.5572
# 97                                    Humberlea, Emery  43.7337  -79.5444
# 98                                              Weston  43.7055  -79.5204
# 99                                           Westmount  43.6963  -79.5331
# 100  Kingsview Village, St. Phillips, Martin Grove ...  43.6869  -79.5655
# 101  South Steeles, Silverstone, Humbergate, Jamest...  43.7441  -79.5812
# 102                Northwest, West Humber - Clairville  43.7116  -79.5884
#
# [103 rows x 5 columns]
